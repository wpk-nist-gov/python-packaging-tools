# %%
import analphipy
import pandas as pd

# %%
data = pd.read_csv("../data/params.csv")
data.head()
# Out:
#    n  m  temp  dens
# 0  4  2   0.5   0.1
# 1  4  2   1.0   0.1
# 2  4  2   1.5   0.1
# 3  4  2   2.0   0.1
# 4  4  2   3.0   0.1

# %%
p = analphipy.potential.LennardJonesNM(n=10, m=4)
nf = p.to_nf()

nf.sig(beta=1 / 0.5)
# Out:
# 1.0517727725050474

# %%
def calculate_effective_density(n, m, temp, dens):
    p = analphipy.potential.LennardJonesNM(n=n, m=m)
    nf = p.to_nf()

    sig = nf.sig(beta=1 / temp)

    return dens * sig**3

# %%
dens_eff = []
for _, g in data.iterrows():
    dens_eff.append(calculate_effective_density(n=g.n, m=g.m, temp=g.temp, dens=g.dens))

data_eff = data.assign(dens_eff=dens_eff)

# %%
data_eff
# Out:
#      n  m  temp  dens  dens_eff
# 0    4  2   0.5   0.1  0.142471
# 1    4  2   1.0   0.1  0.116650
# 2    4  2   1.5   0.1  0.101940
# 3    4  2   2.0   0.1  0.091893
# 4    4  2   3.0   0.1  0.078488
# 5    6  3   0.5   0.1  0.126208
# 6    6  3   1.0   0.1  0.110274
# 7    6  3   1.5   0.1  0.100675
# 8    6  3   2.0   0.1  0.093856
# 9    6  3   3.0   0.1  0.084364
# 10   8  4   0.5   0.1  0.118929
# 11   8  4   1.0   0.1  0.107414
# 12   8  4   1.5   0.1  0.100277
# 13   8  4   2.0   0.1  0.095104
# 14   8  4   3.0   0.1  0.087746
# 15  10  5   0.5   0.1  0.114810
# 16  10  5   1.0   0.1  0.105795
# 17  10  5   1.5   0.1  0.100112
# 18  10  5   2.0   0.1  0.095942
# 19  10  5   3.0   0.1  0.089932
# 20  12  6   0.5   0.1  0.112161
# 21  12  6   1.0   0.1  0.104755
# 22  12  6   1.5   0.1  0.100032
# 23  12  6   2.0   0.1  0.096539
# 24  12  6   3.0   0.1  0.091459
# 25  14  7   0.5   0.1  0.110315
# 26  14  7   1.0   0.1  0.104031
# 27  14  7   1.5   0.1  0.099990
# 28  14  7   2.0   0.1  0.096984
# 29  14  7   3.0   0.1  0.092585
# 30  16  8   0.5   0.1  0.108955
# 31  16  8   1.0   0.1  0.103498
# 32  16  8   1.5   0.1  0.099967
# 33  16  8   2.0   0.1  0.097329
# 34  16  8   3.0   0.1  0.093449
# 35  18  9   0.5   0.1  0.107912
# 36  18  9   1.0   0.1  0.103089
# 37  18  9   1.5   0.1  0.099954
# 38  18  9   2.0   0.1  0.097603
# 39  18  9   3.0   0.1  0.094133
